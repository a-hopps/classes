# %% [markdown]
# **Modern Baseline CNN**

# %%
from google.colab import drive
drive.mount('/content/drive')

print("Google Drive mounted.")
# Out:
# Mounted at /content/drive
# Google Drive mounted.

# %% [markdown]
# Dataset Preparation

# %%
import torch
import torchvision
import torchvision.transforms as transforms

# Global transformations
transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
]) ## This section written by gemini

def get_dataloaders(split_name, batch_size=64):
    train_dataset = torchvision.datasets.EMNIST(
        root='./data', train=True, split=split_name, download=True, transform=transform
    )
    test_dataset = torchvision.datasets.EMNIST(
        root='./data', train=False, split=split_name, download=True, transform=transform
    )
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    # Determine number of classes from the dataset labels
    num_classes = len(train_dataset.classes)
    return train_loader, test_loader, num_classes

# %% [markdown]
# Final Model Definition

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ModernCNN(nn.Module):
    def __init__(self, num_classes):
        super(ModernCNN, self).__init__()
        # Layer 1: 16 filters, 5x5 kernel, padding=2 to keep 32x32
        self.conv1 = nn.Conv2d(1, 16, kernel_size=5, padding=2)
        self.bn1 = nn.BatchNorm2d(16)

        # Layer 2: 32 filters, 3x3 kernel, padding=1 to keep size
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(32)

        # Layer 3: 64 filters, 3x3 kernel, padding=1
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(64)

        # Global transition: Adaptive Avg Pool to bring spatial dim to 4x4
        self.avgpool = nn.AdaptiveAvgPool2d((4, 4))

        # Fully Connected Layers
        self.fc1 = nn.Linear(64 * 4 * 4, 256)
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(256, num_classes)

    def forward(self, x):
        # Conv 1: 32x32 -> 16x16
        x = F.max_pool2d(F.relu(self.bn1(self.conv1(x))), 2)
        # Conv 2: 16x16 -> 8x8
        x = F.max_pool2d(F.relu(self.bn2(self.conv2(x))), 2)
        # Conv 3: 8x8 -> 4x4
        x = F.max_pool2d(F.relu(self.bn3(self.conv3(x))), 2)

        x = self.avgpool(x)
        x = x.view(x.size(0), -1)

        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
import torch.optim as optim
import os

def train_evaluate_save(split_name, epochs=20):
    print(f"\n--- Processing EMNIST split: {split_name} ---")
    save_base_dir = '/content/drive/MyDrive/cs320/final project/models'
    os.makedirs(save_base_dir, exist_ok=True) # written by gemini

    train_loader, test_loader, num_classes = get_dataloaders(split_name)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = ModernCNN(num_classes).to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(1, epochs + 1):
        model.train()
        total_loss = 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f"[{split_name}] Epoch {epoch} Avg Loss: {total_loss/len(train_loader):.4f}")

        # Save model at specific epochs to Google Drive
        if epoch == 5 or epoch == 10 or epoch == 20:
            save_path_epoch = os.path.join(save_base_dir, f"modern_{split_name}_epoch_{epoch}.pth")
            torch.save(model.state_dict(), save_path_epoch)
            print(f"Model saved to {save_path_epoch} at epoch {epoch}")
            ## Saving section written by gemini

    # Evaluation
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    print(f"Accuracy on {split_name}: {accuracy:.2f}%")

    # Save Final State to Google Drive
    final_save_path = os.path.join(save_base_dir, f"modern_{split_name}_final.pth")
    torch.save(model.state_dict(), final_save_path)
    print(f"Final model saved to {final_save_path}")
    return accuracy

# Execute for each split
splits = ['bymerge', 'byclass', 'balanced']
results = {}

for s in splits:
    results[s] = train_evaluate_save(s, epochs=20)

print("\nSummary of Results:")
for split, acc in results.items():
    print(f"{split}: {acc:.2f}%")
# Out:
# --- Processing EMNIST split: bymerge ---
#  41%|████      | 231M/562M [00:01<00:01, 215MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2908/2086808408.py in <cell line: 0>()
#      61 # Ensure epochs is set to at least 20 to reach all save points
#      62 for s in splits:
# ---> 63     results[s] = train_evaluate_save(s, epochs=20)
#      64
#      65 print("\nSummary of Results:")
#
# /tmp/ipykernel_2908/2086808408.py in train_evaluate_save(split_name, epochs)
#       7     os.makedirs(save_base_dir, exist_ok=True)
#       8
# ----> 9     train_loader, test_loader, num_classes = get_dataloaders(split_name)
#      10
#      11     device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#
# /tmp/ipykernel_2908/1692132614.py in get_dataloaders(split_name, batch_size)
#      11
#      12 def get_dataloaders(split_name, batch_size=64):
# ---> 13     train_dataset = torchvision.datasets.EMNIST(
#      14         root='./data', train=True, split=split_name, download=True, transform=transform
#      15     )
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/mnist.py in __init__(self, root, split, **kwargs)
#     297         self.training_file = self._training_file(split)
#     298         self.test_file = self._test_file(split)
# --> 299         super().__init__(root, **kwargs)
#     300         self.classes = self.classes_split_dict[self.split]
#     301
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/mnist.py in __init__(self, root, train, transform, target_transform, download)
#      98
#      99         if download:
# --> 100             self.download()
#     101
#     102         if not self._check_exists():
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/mnist.py in download(self)
#     334         os.makedirs(self.raw_folder, exist_ok=True)
#     335
# --> 336         download_and_extract_archive(self.url, download_root=self.raw_folder, md5=self.md5)
#     337         gzip_folder = os.path.join(self.raw_folder, "gzip")
#     338         for gzip_file in os.listdir(gzip_folder):
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/utils.py in download_and_extract_archive(url, download_root, extract_root, filename, md5, remove_finished)
#     386         filename = os.path.basename(url)
#     387
# --> 388     download_url(url, download_root, filename, md5)
#     389
#     390     archive = os.path.join(download_root, filename)
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/utils.py in download_url(url, root, filename, md5, max_redirect_hops)
#     125         # download the file
#     126         try:
# --> 127             _urlretrieve(url, fpath)
#     128         except (urllib.error.URLError, OSError) as e:  # type: ignore[attr-defined]
#     129             if url[:5] == "https":
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/utils.py in _urlretrieve(url, filename, chunk_size)
#      28     with urllib.request.urlopen(urllib.request.Request(url, headers={"User-Agent": USER_AGENT})) as response:
#      29         with open(filename, "wb") as fh, tqdm(total=response.length, unit="B", unit_scale=True) as pbar:
# ---> 30             while chunk := response.read(chunk_size):
#      31                 fh.write(chunk)
#      32                 pbar.update(len(chunk))
#
# /usr/lib/python3.12/http/client.py in read(self, amt)
#     477                 # clip the read to the "end of response"
#     478                 amt = self.length
# --> 479             s = self.fp.read(amt)
#     480             if not s and amt:
#     481                 # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.12/socket.py in readinto(self, b)
#     718         while True:
#     719             try:
# --> 720                 return self._sock.recv_into(b)
#     721             except timeout:
#     722                 self._timeout_occurred = True
#
# /usr/lib/python3.12/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1249                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250                   self.__class__)
# -> 1251             return self.read(nbytes, buffer)
#    1252         else:
#    1253             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.12/ssl.py in read(self, len, buffer)
#    1101         try:
#    1102             if buffer is not None:
# -> 1103                 return self._sslobj.read(len, buffer)
#    1104             else:
#    1105                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# Model Evaluation

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import os

def evaluate_model_comprehensive(model, test_loader, device, split_name):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='weighted', zero_division=0)
    recall = recall_score(all_labels, all_preds, average='weighted', zero_division=0)
    f1 = f1_score(all_labels, all_preds, average='weighted', zero_division=0)

    print(f"Metrics for {split_name}:")
    print(f"  Accuracy:  {accuracy:.4f}")
    print(f"  Precision: {precision:.4f}")
    print(f"  Recall:    {recall:.4f}")
    print(f"  F1 Score:  {f1:.4f}\n")
    ## Gemini wrote this print formatting

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1}

# %%
save_base_dir = '/content/drive/MyDrive/cs320/final project/models'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
splits_to_eval = ['bymerge','byclass', 'balanced']
final_results = {}

for split in splits_to_eval:
    print(f"--- Evaluating final model for split: {split} ---")
    train_loader, test_loader, num_classes = get_dataloaders(split)

    # Initialize model and load weights
    model = ModernCNN(num_classes).to(device)
    model_path = os.path.join(save_base_dir, f"modern_{split}_final.pth")

    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path, map_location=device))
        final_results[split] = evaluate_model_comprehensive(model, test_loader, device, split)
    else:
        print(f"Model file not found at {model_path}")
        print(f"  F1-Score: {metrics['f1_score']:.4f}")
# Out:
# --- Evaluating final model for split: bymerge ---
# Metrics for bymerge:
#   Accuracy:  0.9073
#   Precision: 0.9074
#   Recall:    0.9073
#   F1 Score:  0.9024
#
# --- Evaluating final model for split: byclass ---
# Metrics for byclass:
#   Accuracy:  0.8727
#   Precision: 0.8635
#   Recall:    0.8727
#   F1 Score:  0.8589
#
# --- Evaluating final model for split: balanced ---
# Metrics for balanced:
#   Accuracy:  0.8897
#   Precision: 0.8938
#   Recall:    0.8897
#   F1 Score:  0.8887

# %% [markdown]
# Custom Dataset

# %%
import os
import torch
from PIL import Image, ImageOps
import torchvision.transforms as transforms

# --- 1. Label Mappings ---

# Map your custom file numbers to the actual lowercase characters
custom_to_char = {
    1: 'q', 2: 'l', 3: 'p', 4: 'o', 5: 'w', 6: 't', 7: 'v', 8: 'n',
    9: 'h', 10: 'g', 11: 'f', 12: 'd', 13: 'k', 14: 'a', 15: 'c',
    16: 'u', 17: 'j', 18: 'x', 19: 'i', 20: 's', 21: 'e', 22: 'r',
    23: 'b', 24: 'z', 25: 'y', 26: 'm'
}

# Map characters to EMNIST 'byclass' indices (lowercase 'a' is 36, 'z' is 61)
char_to_emnist_byclass = {chr(i + 97): i + 36 for i in range(26)}

def preprocess_custom_image(image_path, is_dark_text=True, fix_emnist_rotation=True):
    # 1. Load image in grayscale
    img = Image.open(image_path).convert('L')

    # 2. Invert so text is white on black background
    if is_dark_text:
        img = ImageOps.invert(img)

    # 3. THRESHOLDING: Force dark greys (shadows/paper) to pure black and text to pure white
    # Anything below the pixel value of 100 becomes 0. You can tweak this number (e.g., 80 to 150)
    # if your lighting was particularly bright or dark!
    img = img.point(lambda p: 255 if p > 100 else 0)

    # 4. AUTO-CROPPING: Remove empty black space so the letter fills the frame like EMNIST
    bbox = img.getbbox() # Gets bounding box of the non-black pixels
    if bbox:
        img = img.crop(bbox)

    # 5. Padding & Resizing: Add a tiny 15% border (standard for EMNIST), then resize to 32x32
    padding = max(img.size) // 6
    img = ImageOps.expand(img, border=padding, fill=0)
    img = img.resize((32, 32), Image.Resampling.BILINEAR)

    # 6. Fix EMNIST Rotation Quirk
    if fix_emnist_rotation:
        img = img.rotate(-90, expand=True)
        img = ImageOps.mirror(img)

    # 7. Convert to tensor and apply your training normalization
    transform_pipeline = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
    ])

    return transform_pipeline(img).unsqueeze(0)

# --- Full EMNIST Decoder Dictionary ---
emnist_decoder = {}
for i in range(10): emnist_decoder[i] = str(i)             # 0-9
for i in range(26): emnist_decoder[i + 10] = chr(i + 65)   # A-Z
for i in range(26): emnist_decoder[i + 36] = chr(i + 97)   # a-z

# --- 3. Evaluation Loop ---
def evaluate_custom_dataset(model, folder_path, device):
    model.eval()

    results = {
        'total': {'strict_correct': 0, 'case_insensitive_correct': 0, 'count': 0},
        'messy': {'strict_correct': 0, 'case_insensitive_correct': 0, 'count': 0},
        'print': {'strict_correct': 0, 'case_insensitive_correct': 0, 'count': 0}
    }

    print(f"Evaluating images in: {folder_path}...\n")

    with torch.no_grad():
        for filename in os.listdir(folder_path):
            if not filename.endswith(('.png', '.jpg', '.jpeg')):
                continue

            parts = filename.replace('.png', '').replace('.jpg', '').split('_')
            if len(parts) != 3:
                continue

            writing_type = parts[1]
            custom_class = int(parts[2])

            true_char_lower = custom_to_char[custom_class]
            true_emnist_label = char_to_emnist_byclass[true_char_lower]

            img_path = os.path.join(folder_path, filename)
            img_tensor = preprocess_custom_image(img_path).to(device)

            outputs = model(img_tensor)
            _, predicted_label = torch.max(outputs.data, 1)
            predicted_label = predicted_label.item()

            # Use our new decoder to get the actual predicted letter!
            pred_char = emnist_decoder[predicted_label]

            # --- Check Accuracy ---
            # Strict: Must match exactly (e.g., lowercase 'w' == lowercase 'w')
            strict_match = (predicted_label == true_emnist_label)

            # Case-Insensitive: Matches if letters are the same, regardless of case
            case_match = (pred_char.lower() == true_char_lower.lower())

            # Update stats
            results['total']['count'] += 1
            results[writing_type]['count'] += 1

            if strict_match:
                results['total']['strict_correct'] += 1
                results[writing_type]['strict_correct'] += 1
            if case_match:
                results['total']['case_insensitive_correct'] += 1
                results[writing_type]['case_insensitive_correct'] += 1

            # Print failures (only print if it failed the case-insensitive check)
            if not case_match:
                print(f"True Mistake on {filename}: True={true_char_lower}, Predicted={pred_char}")

    # --- Print Summary ---
    print("\n--- Custom Dataset Results ---")
    for category in ['total', 'messy', 'print']:
        count = results[category]['count']
        if count > 0:
            strict_acc = results[category]['strict_correct'] / count * 100
            case_acc = results[category]['case_insensitive_correct'] / count * 100
            print(f"{category.capitalize()} - Strict Accuracy: {strict_acc:.2f}% | Case-Insensitive Accuracy: {case_acc:.2f}%")

# --- 4. Execution ---

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

num_classes = 62
model = ModernCNN(num_classes).to(device)

# 3. Load the Weights
model_path = "/content/drive/MyDrive/cs320/final project/models/modern_byclass_final.pth"

if os.path.exists(model_path):
    model.load_state_dict(torch.load(model_path, map_location=device))
    print(f"Successfully loaded model weights from {model_path}")

    folder_dir = "/content/drive/MyDrive/cs320/final project/handwriting_data"

    if os.path.exists(folder_dir):
        evaluate_custom_dataset(model, folder_dir, device)
    else:
        print(f"Error: Could not find image folder at {folder_dir}. Check the path.")
else:
    print(f"Error: Could not find model file at {model_path}. Check the path.")
# Out:
# Using device: cuda
# Successfully loaded model weights from /content/drive/MyDrive/cs320/final project/models/modern_byclass_final.pth
# Evaluating images in: /content/drive/MyDrive/cs320/final project/handwriting_data...
#
# True Mistake on sample5_messy_1.png: True=q, Predicted=B
# True Mistake on sample4_messy_9.png: True=h, Predicted=8
# True Mistake on sample3_messy_2.png: True=l, Predicted=B
# True Mistake on sample4_messy_3.png: True=p, Predicted=q
# True Mistake on sample4_messy_19.png: True=i, Predicted=B
# True Mistake on sample5_print_19.png: True=i, Predicted=R
# True Mistake on sample5_messy_20.png: True=s, Predicted=5
# True Mistake on sample5_messy_22.png: True=r, Predicted=Q
# True Mistake on sample4_messy_1.png: True=q, Predicted=a
# True Mistake on sample5_messy_8.png: True=n, Predicted=B
# True Mistake on sample4_print_3.png: True=p, Predicted=B
# True Mistake on sample5_messy_15.png: True=c, Predicted=z
# True Mistake on sample5_print_6.png: True=t, Predicted=H
# True Mistake on sample5_messy_21.png: True=e, Predicted=G
# True Mistake on sample4_messy_21.png: True=e, Predicted=g
# True Mistake on sample5_messy_13.png: True=k, Predicted=b
# True Mistake on sample5_messy_10.png: True=g, Predicted=a
# True Mistake on sample3_messy_14.png: True=a, Predicted=B
# True Mistake on sample4_print_6.png: True=t, Predicted=F
# True Mistake on sample5_messy_2.png: True=l, Predicted=8
# True Mistake on sample5_messy_19.png: True=i, Predicted=E
# True Mistake on sample5_messy_4.png: True=o, Predicted=Q
# True Mistake on sample5_messy_24.png: True=z, Predicted=E
# True Mistake on sample3_messy_7.png: True=v, Predicted=B
# True Mistake on sample3_messy_11.png: True=f, Predicted=B
# True Mistake on sample4_messy_18.png: True=x, Predicted=8
# True Mistake on sample4_messy_7.png: True=v, Predicted=W
# True Mistake on sample5_print_3.png: True=p, Predicted=r
# True Mistake on sample5_print_2.png: True=l, Predicted=n
# True Mistake on sample4_print_19.png: True=i, Predicted=F
# True Mistake on sample3_messy_9.png: True=h, Predicted=W
# True Mistake on sample4_print_2.png: True=l, Predicted=M
# True Mistake on sample4_messy_16.png: True=u, Predicted=B
# True Mistake on sample5_messy_3.png: True=p, Predicted=B
# True Mistake on sample3_messy_3.png: True=p, Predicted=8
# True Mistake on sample5_print_17.png: True=j, Predicted=3
# True Mistake on sample3_messy_16.png: True=u, Predicted=B
# True Mistake on sample3_messy_13.png: True=k, Predicted=B
# True Mistake on sample3_messy_10.png: True=g, Predicted=8
# True Mistake on sample3_messy_6.png: True=t, Predicted=B
# True Mistake on sample5_print_1.png: True=q, Predicted=e
# True Mistake on sample5_messy_6.png: True=t, Predicted=E
# True Mistake on sample4_messy_2.png: True=l, Predicted=A
# True Mistake on sample5_messy_18.png: True=x, Predicted=z
# True Mistake on sample5_print_15.png: True=c, Predicted=0
# True Mistake on sample3_messy_17.png: True=j, Predicted=B
# True Mistake on sample4_messy_11.png: True=f, Predicted=B
# True Mistake on sample5_messy_23.png: True=b, Predicted=Z
# True Mistake on sample3_messy_1.png: True=q, Predicted=d
# True Mistake on sample4_messy_4.png: True=o, Predicted=9
# True Mistake on sample3_messy_5.png: True=w, Predicted=B
# True Mistake on sample4_messy_22.png: True=r, Predicted=B
# True Mistake on sample4_messy_8.png: True=n, Predicted=8
# True Mistake on sample5_print_4.png: True=o, Predicted=e
# True Mistake on sample4_messy_24.png: True=z, Predicted=B
# True Mistake on sample5_messy_7.png: True=v, Predicted=M
# True Mistake on sample4_messy_25.png: True=y, Predicted=B
# True Mistake on sample4_messy_10.png: True=g, Predicted=B
# True Mistake on sample5_messy_11.png: True=f, Predicted=B
# True Mistake on sample3_messy_4.png: True=o, Predicted=E
# True Mistake on sample5_messy_14.png: True=a, Predicted=2
# True Mistake on sample4_messy_12.png: True=d, Predicted=a
# True Mistake on sample4_messy_15.png: True=c, Predicted=B
# True Mistake on sample4_messy_14.png: True=a, Predicted=M
# True Mistake on sample4_messy_17.png: True=j, Predicted=B
# True Mistake on sample5_print_7.png: True=v, Predicted=M
# True Mistake on sample4_messy_20.png: True=s, Predicted=G
# True Mistake on sample3_messy_8.png: True=n, Predicted=B
# True Mistake on sample4_print_16.png: True=u, Predicted=0
# True Mistake on sample3_messy_15.png: True=c, Predicted=B
# True Mistake on sample5_print_5.png: True=w, Predicted=M
# True Mistake on sample5_messy_25.png: True=y, Predicted=a
# True Mistake on sample5_messy_9.png: True=h, Predicted=B
# True Mistake on sample1_print_11.png: True=f, Predicted=h
# True Mistake on sample2_print_4.png: True=o, Predicted=B
# True Mistake on sample2_print_22.png: True=r, Predicted=g
# True Mistake on sample1_print_6.png: True=t, Predicted=K
# True Mistake on sample3_print_21.png: True=e, Predicted=2
# True Mistake on sample2_messy_2.png: True=l, Predicted=N
# True Mistake on sample2_print_1.png: True=q, Predicted=g
# True Mistake on sample2_print_6.png: True=t, Predicted=B
# True Mistake on sample1_messy_19.png: True=i, Predicted=F
# True Mistake on sample2_messy_9.png: True=h, Predicted=B
# True Mistake on sample2_print_15.png: True=c, Predicted=W
# True Mistake on sample2_messy_15.png: True=c, Predicted=B
# True Mistake on sample3_messy_21.png: True=e, Predicted=B
# True Mistake on sample1_print_16.png: True=u, Predicted=V
# True Mistake on sample3_messy_25.png: True=y, Predicted=q
# True Mistake on sample2_messy_20.png: True=s, Predicted=a
# True Mistake on sample1_print_7.png: True=v, Predicted=M
# True Mistake on sample2_messy_22.png: True=r, Predicted=a
# True Mistake on sample3_messy_18.png: True=x, Predicted=B
# True Mistake on sample3_print_7.png: True=v, Predicted=U
# True Mistake on sample3_print_9.png: True=h, Predicted=W
# True Mistake on sample3_print_4.png: True=o, Predicted=0
# True Mistake on sample1_messy_26.png: True=m, Predicted=B
# True Mistake on sample1_messy_16.png: True=u, Predicted=N
# True Mistake on sample1_messy_1.png: True=q, Predicted=8
# True Mistake on sample2_messy_24.png: True=z, Predicted=a
# True Mistake on sample3_print_19.png: True=i, Predicted=l
# True Mistake on sample3_messy_19.png: True=i, Predicted=M
# True Mistake on sample2_messy_17.png: True=j, Predicted=q
# True Mistake on sample3_print_25.png: True=y, Predicted=3
# True Mistake on sample2_print_18.png: True=x, Predicted=e
# True Mistake on sample1_print_15.png: True=c, Predicted=L
# True Mistake on sample3_print_2.png: True=l, Predicted=a
# True Mistake on sample2_print_16.png: True=u, Predicted=W
# True Mistake on sample2_messy_13.png: True=k, Predicted=A
# True Mistake on sample2_messy_18.png: True=x, Predicted=a
# True Mistake on sample2_messy_7.png: True=v, Predicted=B
# True Mistake on sample2_print_8.png: True=n, Predicted=M
# True Mistake on sample2_print_13.png: True=k, Predicted=e
# True Mistake on sample2_messy_16.png: True=u, Predicted=B
# True Mistake on sample1_messy_12.png: True=d, Predicted=t
# True Mistake on sample1_messy_7.png: True=v, Predicted=M
# True Mistake on sample1_print_12.png: True=d, Predicted=2
# True Mistake on sample2_print_19.png: True=i, Predicted=B
# True Mistake on sample3_print_22.png: True=r, Predicted=M
# True Mistake on sample2_messy_1.png: True=q, Predicted=B
# True Mistake on sample1_messy_17.png: True=j, Predicted=S
# True Mistake on sample1_messy_18.png: True=x, Predicted=8
# True Mistake on sample1_print_14.png: True=a, Predicted=U
# True Mistake on sample1_messy_21.png: True=e, Predicted=B
# True Mistake on sample2_messy_19.png: True=i, Predicted=B
# True Mistake on sample1_messy_22.png: True=r, Predicted=D
# True Mistake on sample1_print_4.png: True=o, Predicted=Q
# True Mistake on sample1_messy_4.png: True=o, Predicted=B
# True Mistake on sample2_messy_4.png: True=o, Predicted=B
# True Mistake on sample2_print_21.png: True=e, Predicted=B
# True Mistake on sample2_messy_25.png: True=y, Predicted=4
# True Mistake on sample1_messy_2.png: True=l, Predicted=1
# True Mistake on sample2_messy_8.png: True=n, Predicted=B
# True Mistake on sample2_messy_6.png: True=t, Predicted=a
# True Mistake on sample2_messy_14.png: True=a, Predicted=B
# True Mistake on sample1_messy_20.png: True=s, Predicted=E
# True Mistake on sample1_messy_14.png: True=a, Predicted=0
# True Mistake on sample3_messy_20.png: True=s, Predicted=E
# True Mistake on sample2_messy_12.png: True=d, Predicted=a
# True Mistake on sample1_messy_9.png: True=h, Predicted=M
# True Mistake on sample2_print_14.png: True=a, Predicted=q
# True Mistake on sample2_messy_21.png: True=e, Predicted=B
# True Mistake on sample3_messy_24.png: True=z, Predicted=E
# True Mistake on sample3_messy_22.png: True=r, Predicted=d
# True Mistake on sample3_print_6.png: True=t, Predicted=E
# True Mistake on sample2_print_20.png: True=s, Predicted=y
# True Mistake on sample1_messy_5.png: True=w, Predicted=a
# True Mistake on sample2_print_7.png: True=v, Predicted=g
# True Mistake on sample2_messy_10.png: True=g, Predicted=7
# True Mistake on sample1_messy_13.png: True=k, Predicted=B
# True Mistake on sample2_messy_5.png: True=w, Predicted=B
# True Mistake on sample2_messy_3.png: True=p, Predicted=B
# True Mistake on sample2_messy_23.png: True=b, Predicted=a
# True Mistake on sample1_messy_15.png: True=c, Predicted=E
# True Mistake on sample2_print_2.png: True=l, Predicted=1
# True Mistake on sample2_messy_11.png: True=f, Predicted=g
# True Mistake on sample2_print_17.png: True=j, Predicted=d
# True Mistake on sample1_messy_25.png: True=y, Predicted=W
# True Mistake on sample1_print_2.png: True=l, Predicted=1
# True Mistake on sample1_messy_24.png: True=z, Predicted=B
# True Mistake on sample1_print_21.png: True=e, Predicted=C
# True Mistake on sample1_print_22.png: True=r, Predicted=n
#
# --- Custom Dataset Results ---
# Total - Strict Accuracy: 20.77% | Case-Insensitive Accuracy: 38.08%
# Messy - Strict Accuracy: 8.46% | Case-Insensitive Accuracy: 15.38%
# Print - Strict Accuracy: 33.08% | Case-Insensitive Accuracy: 60.77%
